# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
#Student2_200cAgent
path = os.path.join('data', 'training')
file = 'NeuralAgent_BattleRoyal_rng.csv'
df = pd.read_csv(os.path.join(path,file))
#print(df.head(1))
avg=[]
key =[]
for i in range(1,df.values.shape[1]):
    avg.append(np.sum(df.values[200:,i])/800)
    key.append(df.keys()[i])
print(key[np.argmax(np.array(avg))])
plt.plot(df['NeuralAgent_BattleRoyal_rng'])
plt.plot(df['Student1_200aAgent'])
plt.plot(df['TitFTatAgent'])
plt.legend(['NeuralAgent_BattleRoyal', 'Student1_200aAgent', 'TitFTatAgent'])
# Out:
# Student1_200aAgent

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

path = os.path.join('data', 'simulations')
file = 'Matrix_avgPlayers.csv'
df = pd.read_csv(os.path.join(path,file))

fig = plt.figure(figsize=(10, 10))
ax = fig.subplots()
im = ax.imshow(df.values[:,1:])

cbar = ax.figure.colorbar(im, ax=ax)

# %%
print(df.keys()[37])
# Out:
# Student13_200bAgent

# %%
print(df['Student13_200aAgent'])
# Out:
# 0     2.530
# 1     2.840
# 2     2.175
# 3     2.555
# 4     2.220
#       ...
# 61    1.845
# 62    0.000
# 63    4.980
# 64    2.320
# 65    1.845
# Name: Student13_200aAgent, Length: 66, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

path = os.path.join('data', 'training')
file = 'NeuralAgent_BattleRoyal_rng.csv'
df = pd.read_csv(os.path.join(path,file))

fig = plt.figure(figsize=(20, 20))
ax = fig.subplots()
im = ax.imshow(df.values[-25:,1:])

cbar = ax.figure.colorbar(im, ax=ax)

# %%
print(df.keys()[30])
# Out:
# Student26_200mAgent
