# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
#Student2_200cAgent
path = os.path.join('data', 'training')
file = 'NeuralAgentOpMe_Student1_200aAgent_rng.csv'
df = pd.read_csv(os.path.join(path,file))
#print(df.head(1))
avg=[]
key =[]
for i in range(1,df.values.shape[1]):
    avg.append(np.sum(df.values[200:,i])/800)
    key.append(df.keys()[i])
print(key[np.argmax(np.array(avg))])

#plt.plot(df['Student1_200aAgent'])
plt.plot(df.values[:,1:])
#plt.plot(df['NeuralAgent_BattleRoyal'])
#plt.legend(['NeuralAgent_BattleRoyal', 'Student1_200aAgent', 'TitFTatAgent'])
# Out:
# NeuralAgentOpMe_Student1_200aAgent_rng
# ...

# %%
import numpy as np
from scipy.fftpack import rfft, irfft, fftfreq
def BandFilter(signal,time=1,lowerBound=0,higherBound=100):
    #time  = np.linspace(0,10,2000)
    #signal = np.cos(5*np.pi*time) + np.cos(7*np.pi*time)

    W = fftfreq(signal.size, d=time)
    f_signal = rfft(signal)

    # If our original signal time was in seconds, this is now in Hz
    cut_f_signal = f_signal.copy()

    cut_f_signal[(W < lowerBound)] = 0
    cut_f_signal[(W > higherBound)] = 0

    cut_signal = irfft(cut_f_signal)
    return cut_signal

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

SMALL_SIZE = 8
MEDIUM_SIZE = 13
Big_SIZE = 28

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=Big_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
#plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
#plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
#plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

path = os.path.join('data', 'simulations')
file = 'Matrix_avgPlayers_rng.csv'
df = pd.read_csv(os.path.join(path,file))

fig = plt.figure(figsize=(20, 20))
ax = fig.subplots()
im = ax.imshow(df.values[:,1:].T)
#name_list =  ['NeuralAgent_Student17_200mAgent_rng.h5','NeuralAgent_BattleRoyal_rng.h5','NeuralAgent_Student1_200cAgent_rng.h5','NeuralAgent_Student13_200mAgent_rng.h5','NeuralAgent_Student19_200aAgent_rng.h5','NeuralAgent_Student26_200mAgent_rng.h5','NeuralAgent_Student19_200mAgent_rng.h5','NeuralAgent_Student16_200cAgent_rng.h5','NeuralAgent_Student24_200mAgent_rng.h5','NeuralAgent_Student1_200aAgent_rng.h5','NeuralAgent_Student24_200cAgent_rng.h5','NeuralAgent_Student13_200bAgent_rng.h5','NeuralAgent_Student1_200bAgent_rng.h5','NeuralAgent_Student17_200bAgent_rng.h5','NeuralAgent_Student13_200aAgent_rng.h5','NeuralAgent_AlwaysDefectAgent_rng.h5','NeuralAgent_Student23_200mAgent_rng.h5','NeuralAgent_Student26_200bAgent_rng.h5','NeuralAgent_Student26_200cAgent_rng.h5','NeuralAgent_Student16_200bAgent_rng.h5','NeuralAgent_Student21_200cAgent_rng.h5','NeuralAgent_Student22_200mAgent_rng.h5','NeuralAgent_Student19_200bAgent_rng.h5','NeuralAgent_Student24_200bAgent_rng.h5','NeuralAgent_Student2_200cAgent_rng.h5','NeuralAgent_TitF2tatAgent_rng.h5','NeuralAgent_RandomChoiceAgent_rng.h5','NeuralAgent_Student13_200cAgent_rng.h5','NeuralAgent_Student21_200aAgent_rng.h5','NeuralAgent_Student17_200aAgent_rng.h5','NeuralAgent_Student2_200aAgent_rng.h5','NeuralAgent_Student19_200cAgent_rng.h5','NeuralAgent_Student1_200mAgent_rng.h5','AlwaysDefectAgent','RandomChoiceAgent','Student13_200aAgent','Student13_200bAgent','Student13_200cAgent','Student13_200mAgent','Student16_200bAgent','Student16_200cAgent','Student17_200aAgent','Student17_200bAgent','Student17_200mAgent','Student19_200aAgent','Student19_200bAgent','Student19_200cAgent','Student19_200mAgent','Student1_200aAgent','Student1_200bAgent','Student1_200cAgent','Student1_200mAgent','Student21_200aAgent','Student21_200cAgent','Student22_200mAgent','Student23_200mAgent','Student24_200bAgent','Student24_200cAgent','Student24_200mAgent','Student26_200bAgent','Student26_200cAgent','Student26_200mAgent','Student2_200aAgent','Student2_200cAgent','TitF2tatAgent','TitFTatAgent']
name_list = df.keys()[1:]
cbar = ax.figure.colorbar(im, ax=ax)

ax.set_xticks(np.arange(len(name_list)))
ax.set_yticks(np.arange(len(name_list)))
# ... and label them with the respective list entries
ax.set_xticklabels(name_list)
ax.set_yticklabels(name_list)

# Rotate the tick labels and set their alignment.
plt.setp(ax.get_xticklabels(), rotation=90, ha="right",
         rotation_mode="anchor")

plt.title('Hetmap showing all strategies playing against each other' )

plt.savefig('HeatMapOpMe.png')
plt.show()

# %%
print(df.head(5))
print(df.values[:5,:])
# Out:
#    Unnamed: 0  NeuralAgentOpMe_Student17_200bAgent_rng.h5  \
# 0           0                                       2.575
# 1           1                                       2.758
# 2           2                                       1.567
# 3           3                                       1.226
# 4           4                                       2.558
#
#    NeuralAgentOpMe_Student16_200cAgent_rng.h5  \
# 0                                       2.003
# 1                                       2.570
# 2                                       1.416
# 3                                       1.304
# 4                                       2.302
#
#    NeuralAgentOpMe_RandomChoiceAgent_rng.h5  \
# 0                                     2.557
# 1                                     3.091
# 2                                     1.993
# 3                                     1.390
# 4                                     2.726
#
#    NeuralAgentOpMe_Student1_200bAgent_rng.h5  \
# ...

# %%
print(df['Student13_200aAgent'])
# Out:
# 0     2.530
# 1     2.840
# 2     2.175
# 3     2.555
# 4     2.220
#       ...
# 61    1.845
# 62    0.000
# 63    4.980
# 64    2.320
# 65    1.845
# Name: Student13_200aAgent, Length: 66, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

path = os.path.join('data', 'training')
file = 'NeuralAgentOpMe_TitF2tatAgent_rng.csv'
df = pd.read_csv(os.path.join(path,file))

fig = plt.figure(figsize=(20, 20))
ax = fig.subplots()
im = ax.plot(df.values[::10,1:])

#cbar = ax.figure.colorbar(im, ax=ax)

# %%
print(df.keys()[30])
# Out:
# Student26_200mAgent
