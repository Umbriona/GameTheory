# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

path = os.path.join('data', 'training')
file = 'NeuralAgent_BattleRoyal_rng.csv'
df = pd.read_csv(os.path.join(path,file))

print(df.head(5))
plt.plot(df['NeuralAgent_BattleRoyal_rng'])
plt.plot(df['Student2_200aAgent'])
plt.plot(df['TitFTatAgent'])
plt.legend(['NeuralAgent_BattleRoyal_rng', 'Student13_200cAgent', 'TitFTatAgent'])
# Out:
#    Unnamed: 0  NeuralAgent_BattleRoyal_rng  AlwaysDefectAgent  \
# 0           0                     1.942879           2.151667
# 1           1                     1.956667           2.198333
# 2           2                     1.835455           2.283788
# 3           3                     1.779848           2.254697
# 4           4                     1.730000           2.152273
#
#    RandomChoiceAgent  Student13_200aAgent  Student13_200bAgent  \
# 0           1.643030             1.585758             1.622727
# 1           1.673939             1.633333             1.823485
# 2           1.777727             1.734242             1.889697
# 3           1.768939             1.734545             1.832576
# 4           1.723636             1.723030             1.951061
#
#    Student13_200cAgent  Student13_200mAgent  Student16_200bAgent  \
# 0             1.899697             1.920909             1.726212
# 1             2.193636             2.083636             1.966667
# 2             2.242121             2.052879             1.758182
# 3             2.225455             1.986667             1.642121
# 4             2.236970             2.105455             1.866212
#
#    Student16_200cAgent  ...  Student24_200bAgent  Student24_200cAgent  \
# 0             1.681818  ...             2.157727             2.137727
# 1             1.844545  ...             2.194697             2.198939
# 2             1.792273  ...             2.203182             2.202576
# 3             1.784697  ...             2.208030             2.209848
# 4             1.848030  ...             2.200152             2.197727
#
#    Student24_200mAgent  Student26_200bAgent  Student26_200cAgent  \
# 0             1.585152             1.960000             1.935758
# 1             1.630758             1.961667             1.973182
# 2             1.624242             1.956212             1.978788
# 3             1.637121             1.952879             1.972879
# 4             1.624848             1.960455             1.980000
#
#    Student26_200mAgent  Student2_200aAgent  Student2_200cAgent  TitF2tatAgent  \
# 0             2.001515            0.018939            1.570909       1.953939
# 1             2.000303            0.018939            1.608636       1.960455
# 2             1.997576            0.018333            1.611364       1.963485
# 3             2.002121            0.018939            1.613636       1.955909
# 4             1.997424            0.018333            1.605455       1.954697
#
#    TitFTatAgent
# 0      2.028485
# 1      2.023636
# 2      2.030909
# 3      2.034091
# 4      2.032576
#
# [5 rows x 35 columns]
